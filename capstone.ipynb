# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

tf.reset_default_graph()
tf.set_random_seed(1)
np.random.seed(52)

int_data = ([5.1,34.5,0,2.21840E+06],
[7.8,39.4,0,2.36790E+06],
[4.5,42.5,0,2.73960E+06],
[5.9,30.5,0,1.55660E+06],
[6.1,38.2,1,2.28250E+06],
[5.4,40.4,1,2.86010E+06],
[2.3,37.8,1,3.34740E+06],
[4.4,43.9,1,2.11780E+06],
[5.1,34.5,0,2.21840E+06],
[2.6,44.3,1,3.80820E+06],
[2,33.9,0,2.60650E+06],
[3.5,31.5,1,2.32820E+06],
[7.7,43.2,1,2.36420E+06],
[7.6,40.9,0,2.25480E+06],
[7.9,32.9,1,2.38090E+06],
[3,41.7,0,2.96630E+06],
[3.3,48,1,2.31420E+06],
[4.5,38.5,0,3.164710E+06],
[2.2,42.8,1,3.71260E+06],
[6.2,32.1,1,1.98210E+06],
[7.8,39.4,0,2.36790E+06],
[4.5,42.5,0,2.73960E+06],
[5.9,30.5,0,1.55660E+06],
[2.7,45.9,0,2.79730E+06],
[7.2,30.8,0,1.58540E+06],
[2.8,31.7,0,2.03210E+06],
[6.9,39,1,2.46080E+06],
[7.5,35.4,1,2.23190E+06],
[4.1,39.9,1,2.25590E+06],
[6.3,36.3,0,2.01610E+06],
[3.6,36.5,1,1.38830E+06],
[5.6,33.3,0,1.88660E+06],
[7.3,34,1,2.17170E+06],
[5.7,30.4,0,1.89550E+06],
[4,48.7,0,2.85480E+06],
[3.7,41.6,0,2.69090E+06],
[4.8,32.7,0,1.81050E+06],
[5.7,45.6,1,3.13290E+06],
[6.6,40.4,0,2.15480E+06],
[4.9,37.4,1,2.70540E+06],
[5.7,45.6,1,3.13290E+06],
[6.6,40.4,0,2.15480E+06],
[4.9,37.4,1,2.70540E+06],
[3.8,44.7,1,3.43110E+06],
[3.8,44.7,1,3.43110E+06],
[6,42.2,1,2.83640E+06],
[2.3,37.8,1,3.34740E+06],
[4.4,43.9,1,2.11780E+06],
[2.7,45.9,0,2.79730E+06],
[7.2,30.8,0,1.58540E+06],
[2.8,31.7,0,2.03210E+06],
[6.9,39,1,2.46080E+06],
[4.8,32.7,0,1.81050E+06],
[6,42.2,1,2.83640E+06],
[5.4,37.2,1,2.62460E+06],
[3.2,35.8,1,2.69520E+06],
[7,35,0,2.13510E+06],
[2.6,44.3,1,3.80820E+06],
[2,33.9,0,2.60650E+06],
[3.5,31.5,1,2.32820E+06],
[7.7,43.2,1,2.36420E+06],
[7.6,40.9,0,2.25480E+06],
[7.9,32.9,1,2.38090E+06],
[3,41.7,0,2.96630E+06],
[7.5,35.4,1,2.23190E+06],
[4.1,39.9,1,2.25590E+06],
[6.3,36.3,0,2.01610E+06],
[3.3,48,1,2.31420E+06],
[4.5,38.5,0,3.164710E+06],
[2.2,42.8,1,3.71260E+06],
[6.2,32.1,1,1.98210E+06],
[3.6,36.5,1,1.38830E+06],
[5.6,33.3,0,1.88660E+06],
[7.3,34,1,2.17170E+06],
[5.7,30.4,0,1.89550E+06],
[4,48.7,0,2.85480E+06],
[3.7,41.6,0,2.69090E+06],)

# min max nomalize 함수
def min_max_nomalize(data):
  return (data - np.min(int_data, 0)) / (np.max(int_data, 0) - np.min(int_data, 0))
# data nomalize    min max로
data = min_max_nomalize(int_data)

int_y_data = data[0:82, :]


# min max 정규화 풀기
def solve_min_max_nomalize(data):
  return (data * (np.max(int_y_data, 0) - np.min(int_y_data, 0)) + np.min(int_y_data, 0))


# data set   트레이닝 40개 테스트 10개 총 50개
x_training = data[:-32, 0:3]
y_training = data[:-32, 3:]
x_validation = data[-32:-18, 0:3]
y_validation = data[-32:-18, 3:]
x_test = data[-18:, 0:3]
y_test = data[-18:, 3:]


X = tf.placeholder(tf.float32, shape=[None, 3])
Y = tf.placeholder(tf.float32, shape=[None, 1])
keep_prob = tf.placeholder(tf.float32)

alpha = 0.005
lamda = 8.8E-05
n_step = 40000
n1 = 33
n1f = 0.43766
n2 = 47
n2f = 0.54464
n3 = 42
n3f =2.008497
drop = 1

  # 레이어 설정 
W1 = tf.get_variable("W1", shape=[3, n1], initializer=tf.keras.initializers.he_normal())
b1 = tf.Variable(tf.random_normal([n1]))
if n1f < 1:
  L1 = tf.nn.sigmoid(tf.matmul(X, W1) + b1)
elif n1f <2:
  L1 =tf.nn.tanh(tf.matmul(X, W1) + b1)
else:
  L1 =tf.nn.relu(tf.matmul(X, W1) + b1)
L1 = tf.nn.dropout(L1, keep_prob=keep_prob)

W2 = tf.get_variable("W2", shape=[n1, n2], initializer=tf.keras.initializers.he_normal())
b2 = tf.Variable(tf.random_normal([n2]))
if n2f < 1:
  L2 = tf.nn.sigmoid(tf.matmul(L1, W2) + b2)
elif n2f <2:
  L2 = tf.nn.tanh(tf.matmul(L1, W2) + b2)
else:
  L2 = tf.nn.relu(tf.matmul(L1, W2) + b2)
L2 = tf.nn.dropout(L2, keep_prob=keep_prob)

W3 = tf.get_variable("W3", shape=[n2, n3], initializer=tf.keras.initializers.he_normal())
b3 = tf.Variable(tf.random_normal([n3]))
if n3f < 1:
  L3 = tf.nn.sigmoid(tf.matmul(L2, W3) + b3)
elif n3f <2:
  L3 = tf.nn.tanh(tf.matmul(L2, W3) + b3)
else:
  L3 = tf.nn.relu(tf.matmul(L2, W3) + b3)
L3 = tf.nn.dropout(L3, keep_prob=keep_prob)

W4 = tf.get_variable("W4", shape=[n3,1], initializer=tf.keras.initializers.he_normal())
b4 = tf.Variable(tf.random_normal([1]))
hypothesis = tf.matmul(L3, W4) + b4

cost_val = []
step_val = []
  #           정규화 람다
regularizer = lamda*(tf.nn.l2_loss(W1) + tf.nn.l2_loss(W2) + tf.nn.l2_loss(W3) + tf.nn.l2_loss(W4))
cost = tf.reduce_mean(tf.square(hypothesis - Y)) + regularizer
  #                                                 러닝 레이트
optimizer = tf.train.MomentumOptimizer(learning_rate=alpha, momentum=0.9).minimize(cost)

with tf.Session() as sess:
      sess.run(tf.global_variables_initializer())
      for step in range(n_step):
          curr_cost, _ = sess.run([cost, optimizer], feed_dict={X: x_training, Y: y_training, keep_prob: drop} )
          step_val.append(step)  # 데이터 배열에 값을 추가 즉 스텝이 반복될 때마다 그 값을 추가
          cost_val.append(curr_cost)
          if step % 30000 == 0:
            print(step, curr_cost)
      prediction = sess.run(hypothesis, feed_dict={X: x_test, keep_prob: 1} )
      prediction2 = sess.run(hypothesis, feed_dict={X: x_training, keep_prob: 1} )      
      prediction3 = sess.run(hypothesis, feed_dict={X: x_validation, keep_prob: 1} )
      cost1 = sess.run(cost, feed_dict={X: x_validation, Y: y_validation, keep_prob: 1} )
      cost2 = sess.run(cost, feed_dict={X: x_training, Y: y_training, keep_prob: 1} )
      costsum = cost1+cost2
      cost_val.append(costsum)
      print(costsum)
      w1b = sess.run(W1)
      w2b = sess.run(W2)
      w3b = sess.run(W3)
      w4b = sess.run(W4)
      b1b = sess.run(b1)
      b2b = sess.run(b2)     
      b3b = sess.run(b3)
      b4b = sess.run(b4)
      
print(prediction)
np.savetxt('data.csv',int_data, delimiter=',')
#np.savetxt('w1b.csv',w1b, delimiter=',')
#np.savetxt('w2b.csv',w2b, delimiter=',')
#np.savetxt('w3b.csv',w3b, delimiter=',')
#np.savetxt('w4b.csv',w4b, delimiter=',')
#np.savetxt('b1b.csv',b1b, delimiter=',')
#np.savetxt('b2b.csv',b2b, delimiter=',')
#np.savetxt('b3b.csv',b3b, delimiter=',')
#np.savetxt('b4b.csv',b4b, delimiter=',')

def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean(0))

def er(predictions, targets):
    return np.abs(((predictions - targets)/prediction).mean(0))


#rmse_val = rmse(prediction, int_y_test)
  
#plt.title('')  # 그래프 제목
#plt.xlabel('step')  # x축 이름
#plt.ylabel('cost')  # y축 이름

#plt.ylim(0,1.5*int_cost)  # y축 그래프 한계
#plt.ylim(0, 0.02)
#plt.plot(step_val, cost_val)
#plt.show()


plt.xlabel('AFDEX')  # x축 이름
plt.ylabel('ANN')  # y축 이름
plt.scatter(y_test, prediction)
plt.plot([0, 1.2], [0,1.2])
plt.show()


plt.xlabel('AFDEX')  # x축 이름
plt.ylabel('ANN')  # y축 이름
plt.scatter(y_training, prediction2)
plt.plot([0, 1.2], [0,1.2])
plt.show()


plt.xlabel('AFDEX')  # x축 이름
plt.ylabel('ANN')  # y축 이름
plt.scatter(y_validation, prediction3)
plt.plot([0, 1.2], [0,1.2])
plt.show()

prediction = solve_min_max_nomalize(prediction)
print(prediction)
prediction2 = solve_min_max_nomalize(prediction2)
prediction3 = solve_min_max_nomalize(prediction3)
y_training = solve_min_max_nomalize(y_training)
y_test = solve_min_max_nomalize(y_test)
y_validation = solve_min_max_nomalize(y_validation)
print(rmse(prediction,y_test))
print(rmse(prediction2,y_training))
print(rmse(prediction3,y_validation))
# Out:
# 0 1.940705
# 30000 0.031147651
# 0.055781752
# [[0.37820888]
#  [0.4847057 ]
#  [0.383919  ]
#  [0.24578846]
#  [0.6064312 ]
#  [0.31490117]
#  [0.5674161 ]
#  [0.298298  ]
#  [0.75292856]
#  [0.44395143]
#  [0.74635965]
#  [0.2784649 ]
#  [0.50605303]
#  [0.23622674]
#  [0.288289  ]
#  [0.14345181]
#  [0.6401873 ]
#  [0.5692596 ]]
# [[0.37820888 0.37820888 0.37820888 0.37820888]
#  [0.48470569 0.48470569 0.48470569 0.48470569]
#  [0.383919   0.383919   0.383919   0.383919  ]
#  [0.24578846 0.24578846 0.24578846 0.24578846]
#  [0.60643119 0.60643119 0.60643119 0.60643119]
#  [0.31490117 0.31490117 0.31490117 0.31490117]
#  [0.56741607 0.56741607 0.56741607 0.56741607]
#  [0.298298   0.298298   0.298298   0.298298  ]
#  [0.75292856 0.75292856 0.75292856 0.75292856]
#  [0.44395143 0.44395143 0.44395143 0.44395143]
#  [0.74635965 0.74635965 0.74635965 0.74635965]
#  [0.27846491 0.27846491 0.27846491 0.27846491]
#  [0.50605303 0.50605303 0.50605303 0.50605303]
# ...

# %%
print(rmse(prediction,y_test))
print(rmse(prediction2,y_training))
print(rmse(prediction3,y_validation))
# Out:
# [0.18500067 0.18500067 0.18500067 0.18500067]
# [0.14779704 0.14779704 0.14779704 0.14779704]
# [0.13678028 0.13678028 0.13678028 0.13678028]

# %%
np.size(y_training1)
# Out:
# 100
